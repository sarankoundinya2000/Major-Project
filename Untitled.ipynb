# %%
import pandas as pd

# %%
final_test = pd.read_csv('final_test.csv')

# %%
final_test
# Out:
#        source_node  destination_node  indicator_link  jaccard_followers  \
# 0           848424            784690               1                  0
# 1           483294           1255532               1                  0
# 2           626190           1729265               1                  0
# 3           947219            425228               1                  0
# 4           991374            975044               1                  0
# ...            ...               ...             ...                ...
# 49997      1167544            310247               0                  0
# 49998       656027           1761965               0                  0
# 49999      1304926            958643               0                  0
# 50000       773347           1488855               0                  0
# 50001      1253866            281538               0                  0
#
#        jaccard_followees  cosine_followers  cosine_followees  inter_followers  \
# ...

# %%
final_test[final_test['indicator_link']==1.0].iloc[:50]
# Out:
#     source_node  destination_node  indicator_link  jaccard_followers  \
# 0        848424            784690               1                  0
# 1        483294           1255532               1                  0
# 2        626190           1729265               1                  0
# 3        947219            425228               1                  0
# 4        991374            975044               1                  0
# 5       1742449            976545               1                  0
# 6       1776080           1098942               1                  0
# 7        561223            964910               1                  0
# 8       1493684            281972               1                  0
# 9       1097040           1463368               1                  0
# 10      1655782           1511551               1                  0
# 11       915549            310481               1                  0
# 12       317576           1148171               1                  0
# ...

# %%
df1 = final_test[final_test['indicator_link']==1.0].iloc[:50]
df2 = final_test[final_test['indicator_link']==0.0].iloc[:50]
final_df = pd.concat([df1, df2], axis=0)

# %%
final_df
# Out:
#        source_node  destination_node  indicator_link  jaccard_followers  \
# 0           848424            784690               1                  0
# 1           483294           1255532               1                  0
# 2           626190           1729265               1                  0
# 3           947219            425228               1                  0
# 4           991374            975044               1                  0
# ...            ...               ...             ...                ...
# 25001      1708269           1747714               0                  0
# 25002      1775820            378487               0                  0
# 25003       675687           1153873               0                  0
# 25004       926795             50696               0                  0
# 25005       353277           1153537               0                  0
#
#        jaccard_followees  cosine_followers  cosine_followees  inter_followers  \
# ...

# %%
final_df.to_csv('Test.csv',index=False)

# %%
test = pd.read_csv('Test.csv')
test
# Out:
#     source_node  destination_node  indicator_link  jaccard_followers  \
# 0        848424            784690               1                  0
# 1        483294           1255532               1                  0
# 2        626190           1729265               1                  0
# 3        947219            425228               1                  0
# 4        991374            975044               1                  0
# ..          ...               ...             ...                ...
# 95      1708269           1747714               0                  0
# 96      1775820            378487               0                  0
# 97       675687           1153873               0                  0
# 98       926795             50696               0                  0
# 99       353277           1153537               0                  0
#
#     jaccard_followees  cosine_followers  cosine_followees  inter_followers  \
# ...

# %%
final_indi= final_df.iloc[:,:3]

# %%
final_indi.to_csv('web_indi.csv',index=False)

# %%
d1=  pd.read_csv('web_indi.csv')

# %%
d1
# Out:
#     source_node  destination_node  indicator_link
# 0        848424            784690               1
# 1        483294           1255532               1
# 2        626190           1729265               1
# 3        947219            425228               1
# 4        991374            975044               1
# ..          ...               ...             ...
# 95      1708269           1747714               0
# 96      1775820            378487               0
# 97       675687           1153873               0
# 98       926795             50696               0
# 99       353277           1153537               0
#
# [100 rows x 3 columns]

# %%
final_nw = final_df.iloc[:,:2]
final_nw.to_csv('web_indi1.csv',index=False,header=False)

# %%
d=  pd.read_csv('web_indi1.csv')

# %%
d
# Out:
#      848424   784690
# 0    483294  1255532
# 1    626190  1729265
# 2    947219   425228
# 3    991374   975044
# 4   1742449   976545
# ..      ...      ...
# 94  1708269  1747714
# 95  1775820   378487
# 96   675687  1153873
# 97   926795    50696
# 98   353277  1153537
#
# [99 rows x 2 columns]

# %%
d1
# Out:
#     1328903   721037
# 0     51902  1563465
# 1    753253   692662
# 2   1820176  1546841
# 3     85195   416809
# 4   1258834  1341559
# ..      ...      ...
# 94   819119  1437161
# 95   191014   828710
# 96   354852  1311092
# 97   169499  1465659
# 98  1552352   330406
#
# [99 rows x 2 columns]

# %%
d
# Out:
#    Source_node Destination_node  Indicator_link
# 0      1328903           721037             0.0
# 1        51902          1563465             0.0
# 2       753253           692662             0.0
# 3      1820176          1546841             0.0
# 4        85195           416809             0.0
# ..         ...              ...             ...
# 95      819119          1437161             1.0
# 96      191014           828710             1.0
# 97      354852          1311092             1.0
# 98      169499          1465659             1.0
# 99     1552352           330406             1.0
#
# [100 rows x 3 columns]

# %%
d.tail(10)
# Out:
#     Source_node  Destination_node  Indicator_link
# 90       781231           1037751             1.0
# 91      1249080            557322             1.0
# 92       513123           1530049             1.0
# 93       104114             57653             1.0
# 94      1249951           1071509             1.0
# 95       819119           1437161             1.0
# 96       191014            828710             1.0
# 97       354852           1311092             1.0
# 98       169499           1465659             1.0
# 99      1552352            330406             1.0

# %%
from datetime import datetime
start = datetime.now()
import streamlit as st
import graphviz as graphviz

 # Create a graphlib graph object
graph = graphviz.Digraph()
for index, row in d.iterrows():
   
    graph.edge(row['Source_node'], row['Destination_node'])

st.graphviz_chart(graph)
print('Time taken :', datetime.now() - start)
# Out:
# Time taken : 0:00:00.306655

# %%
st.graphviz_chart(graph)

# %%
import graphviz as graphviz

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
network = final_df.iloc[:30,:2]

# %%
network.to_csv('network.csv',header=False,index=False)

# %%
subgraph=nx.read_edgelist('network.csv',delimiter=',',create_using=nx.DiGraph(),nodetype=int)
# https://stackoverflow.com/questions/9402255/drawing-a-huge-graph-with-networkx-and-matplotlib

pos=nx.spring_layout(subgraph)
nx.draw(subgraph,pos,node_color='#A0CBE2',edge_color='#00bb5e',width=1,edge_cmap=plt.cm.Blues,with_labels=True)
plt.savefig("graph_sample.pdf")
print(nx.info(subgraph))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 60
# Number of edges: 30
# Average in degree:   0.5000
# Average out degree:   0.5000

# %%
test_csv = pd.read_csv('Test.csv')

# %%
test_csv
# Out:
#     source_node  destination_node  indicator_link  jaccard_followers  \
# 0        848424            784690               1                  0
# 1        483294           1255532               1                  0
# 2        626190           1729265               1                  0
# 3        947219            425228               1                  0
# 4        991374            975044               1                  0
# ..          ...               ...             ...                ...
# 95      1708269           1747714               0                  0
# 96      1775820            378487               0                  0
# 97       675687           1153873               0                  0
# 98       926795             50696               0                  0
# 99       353277           1153537               0                  0
#
#     jaccard_followees  cosine_followers  cosine_followees  inter_followers  \
# ...

# %%
import matplotlib.pyplot as plt
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')

# Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')

# Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')

# Note that this is the same as
plt.subplots(2, 2, sharex=True, sharey=True)

# Create figure number 10 with a single subplot
# and clears it if it already exists.
fig, ax = plt.subplots(num=10, clear=True)

# %%
plt.figure(figsize=(30,15))
